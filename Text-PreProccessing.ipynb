# %% [markdown]
# ## Pre Proccessing Document
#
# ### From Farshad Nematpour
# _______________________________________________________________________
#
# ##### import packages

# %%
import os 
import re
import requests

# %% [markdown]
# ##### Import TXT path

# %%
doc_1 = "https://raw.githubusercontent.com/farshadnp/Data-Mining-Exercises-Code/main/data/1.txt"
doc_2 = "https://raw.githubusercontent.com/farshadnp/Data-Mining-Exercises-Code/main/data/2.txt"
doc_3 = "https://raw.githubusercontent.com/farshadnp/Data-Mining-Exercises-Code/main/data/3.txt"
doc_4 = "https://raw.githubusercontent.com/farshadnp/Data-Mining-Exercises-Code/main/data/4.txt"
doc_5 = "https://raw.githubusercontent.com/farshadnp/Data-Mining-Exercises-Code/main/data/5.txt"
doc_6 = "https://raw.githubusercontent.com/farshadnp/Data-Mining-Exercises-Code/main/data/6.txt"
doc_7 = "https://raw.githubusercontent.com/farshadnp/Data-Mining-Exercises-Code/main/data/7.txt"
doc_8 = "https://raw.githubusercontent.com/farshadnp/Data-Mining-Exercises-Code/main/data/8.txt"
doc_9 = "https://raw.githubusercontent.com/farshadnp/Data-Mining-Exercises-Code/main/data/9.txt"
doc_10 = "https://raw.githubusercontent.com/farshadnp/Data-Mining-Exercises-Code/main/data/10.txt"

# %%
All_Documents_Path = [doc_1,doc_2,doc_3,doc_4,doc_5,doc_6,doc_7,doc_8,doc_9,doc_10]

# %% [markdown]
# #### get from url

# %%
def get_book(MyDoc):
    raw = requests.get(MyDoc).text
    return raw

# %% [markdown]
# #### intialize all documents path as book[i]

# %%
book1= get_book(doc_1)
book2= get_book(doc_2)
book3= get_book(doc_3)
book4= get_book(doc_4)
book5= get_book(doc_5)
book6= get_book(doc_6)
book7= get_book(doc_7)
book8= get_book(doc_8)
book9= get_book(doc_9)
book10= get_book(doc_10)

# %%
All_Book_Raw = book1+book2+book3+book4+book5+book6+book7+book8+book9+book10
type(All_Book_Raw)
# Out:
# str

# %% [markdown]
# ## 1- Sentence Tokenization
# #### strip()   split()    lower()  count()
#
# #### Removing :Tags, URL, Multiply Spaces, Single Charachter , Punctuations
# ##### 1. list terms and split by " " seperator
# ##### 2. TF counter
# ____________________________________

# %%
book1_S= book1.lower().split()

print("Total Word of this document are: ",len(book1_S),"Words.","\n____________________________________________")
for k in range (len(book1_S)):
    TF= book1_S.count(book1_S[k])
    print("index=",k,"| tf=",TF,"|term=",book1_S[k])
# Out:
# Total Word of this document are:  991 Words.
# ____________________________________________
# index= 0 | tf= 8 |term= eur
# index= 1 | tf= 1 |term= futures:
# index= 2 | tf= 2 |term= recovery
# index= 3 | tf= 2 |term= seen
# index= 4 | tf= 1 |term= limitedin
# index= 5 | tf= 3 |term= light
# index= 6 | tf= 20 |term= of
# index= 7 | tf= 1 |term= preliminary
# index= 8 | tf= 1 |term= figures
# index= 9 | tf= 12 |term= for
# index= 10 | tf= 8 |term= eur
# index= 11 | tf= 1 |term= futures
# index= 12 | tf= 1 |term= markets
# index= 13 | tf= 11 |term= from
# index= 14 | tf= 1 |term= cme
# index= 15 | tf= 1 |term= group,
# index= 16 | tf= 1 |term= investors
# index= 17 | tf= 1 |term= scaled
# index= 18 | tf= 2 |term= back
# index= 19 | tf= 1 |term= their
# index= 20 | tf= 3 |term= open
# index= 21 | tf= 2 |term= interest
# index= 22 | tf= 1 |term= positions
# index= 23 | tf= 7 |term= by
# index= 24 | tf= 1 |term= more
# index= 25 | tf= 3 |term= than
# index= 26 | tf= 1 |term= 2k
# index= 27 | tf= 2 |term= contracts
# index= 28 | tf= 21 |term= on
# index= 29 | tf= 1 |term= wednesday
# index= 30 | tf= 11 |term= from
# index= 31 | tf= 1 |term= thursday&rsquo;s
# index= 32 | tf= 1 |term= final
# index= 33 | tf= 1 |term= 497,717
# index= 34 | tf= 2 |term= contracts.
# index= 35 | tf= 1 |term= volume,
# index= 36 | tf= 1 |term= instead
# index= 37 | tf= 1 |term= rose
# index= 38 | tf= 12 |term= for
# index= 39 | tf= 88 |term= the
# index= 40 | tf= 1 |term= first
# index= 41 | tf= 5 |term= time
# index= 42 | tf= 4 |term= after
# index= 43 | tf= 1 |term= four
# index= 44 | tf= 1 |term= consecutive
# index= 45 | tf= 21 |term= daily
# index= 46 | tf= 1 |term= drops,
# index= 47 | tf= 3 |term= this
# index= 48 | tf= 5 |term= time
# index= 49 | tf= 7 |term= by
# index= 50 | tf= 9 |term= around
# index= 51 | tf= 1 |term= 14.4k
# index= 52 | tf= 2 |term= contracts.
# index= 53 | tf= 10 |term= eur/usd
# index= 54 | tf= 1 |term= faces
# index= 55 | tf= 1 |term= strong
# index= 56 | tf= 2 |term= resistance
# index= 57 | tf= 13 |term= at
# index= 58 | tf= 3 |term= 1.1338
# index= 59 | tf= 10 |term= eur/usd
# index= 60 | tf= 9 |term= is
# index= 61 | tf= 1 |term= recovering
# index= 62 | tf= 2 |term= ground
# index= 63 | tf= 12 |term= for
# index= 64 | tf= 88 |term= the
# index= 65 | tf= 4 |term= second
# index= 66 | tf= 2 |term= session
# index= 67 | tf= 31 |term= in
# index= 68 | tf= 10 |term= a
# index= 69 | tf= 2 |term= row
# index= 70 | tf= 1 |term= amidst
# index= 71 | tf= 1 |term= rising
# index= 72 | tf= 1 |term= volume
# index= 73 | tf= 15 |term= and
# index= 74 | tf= 1 |term= shrinking
# index= 75 | tf= 3 |term= open
# index= 76 | tf= 1 |term= interest.
# index= 77 | tf= 4 |term= that
# index= 78 | tf= 1 |term= said,
# index= 79 | tf= 88 |term= the
# index= 80 | tf= 1 |term= continuation
# index= 81 | tf= 20 |term= of
# index= 82 | tf= 88 |term= the
# index= 83 | tf= 2 |term= up
# index= 84 | tf= 1 |term= move
# index= 85 | tf= 4 |term= remains
# index= 86 | tf= 21 |term= on
# index= 87 | tf= 88 |term= the
# index= 88 | tf= 1 |term= cards
# index= 89 | tf= 31 |term= in
# index= 90 | tf= 88 |term= the
# index= 91 | tf= 1 |term= very
# index= 92 | tf= 5 |term= near
# index= 93 | tf= 1 |term= term,
# index= 94 | tf= 2 |term= although
# index= 95 | tf= 10 |term= a
# index= 96 | tf= 1 |term= tough
# index= 97 | tf= 1 |term= barrier
# index= 98 | tf= 2 |term= emerges
# index= 99 | tf= 13 |term= at
# index= 100 | tf= 88 |term= the
# index= 101 | tf= 3 |term= 200-week
# index= 102 | tf= 4 |term= sma
# index= 103 | tf= 13 |term= at
# index= 104 | tf= 1 |term= 1.1338.german
# index= 105 | tf= 4 |term= factory
# index= 106 | tf= 5 |term= orders
# index= 107 | tf= 1 |term= slump
# index= 108 | tf= 2 |term= 4.2%
# index= 109 | tf= 31 |term= in
# index= 110 | tf= 1 |term= feb,
# index= 111 | tf= 10 |term= a
# index= 112 | tf= 2 |term= negative
# index= 113 | tf= 1 |term= surprise
# index= 114 | tf= 1 |term= (eur
# index= 115 | tf= 1 |term= turns
# index= 116 | tf= 1 |term= lower)the
# index= 117 | tf= 4 |term= german
# index= 118 | tf= 4 |term= factory
# index= 119 | tf= 5 |term= orders
# index= 120 | tf= 2 |term= fell
# index= 121 | tf= 3 |term= further
# index= 122 | tf= 31 |term= in
# index= 123 | tf= 88 |term= the
# index= 124 | tf= 3 |term= month
# index= 125 | tf= 20 |term= of
# index= 126 | tf= 2 |term= february,
# index= 127 | tf= 2 |term= adding
# index= 128 | tf= 22 |term= to
# index= 129 | tf= 88 |term= the
# index= 130 | tf= 4 |term= recent
# index= 131 | tf= 1 |term= signs
# index= 132 | tf= 4 |term= that
# index= 133 | tf= 1 |term= europe&rsquo;s
# index= 134 | tf= 1 |term= largest
# index= 135 | tf= 1 |term= economy
# index= 136 | tf= 1 |term= had
# index= 137 | tf= 10 |term= a
# index= 138 | tf= 1 |term= subdued
# index= 139 | tf= 1 |term= start
# index= 140 | tf= 22 |term= to
# index= 141 | tf= 1 |term= 2019
# index= 142 | tf= 2 |term= contracts
# index= 143 | tf= 12 |term= for
# index= 144 | tf= 1 |term= goods
# index= 145 | tf= 1 |term= &lsquo;made
# index= 146 | tf= 31 |term= in
# index= 147 | tf= 1 |term= germany&rsquo;
# index= 148 | tf= 1 |term= were
# index= 149 | tf= 1 |term= down
# index= 150 | tf= 7 |term= by
# index= 151 | tf= 2 |term= 4.2%
# index= 152 | tf= 21 |term= on
# index= 153 | tf= 88 |term= the
# index= 154 | tf= 3 |term= month
# index= 155 | tf= 2 |term= vs.
# index= 156 | tf= 1 |term= 0.3%
# index= 157 | tf= 1 |term= forecast
# index= 158 | tf= 15 |term= and
# index= 159 | tf= 1 |term= -2.6%
# index= 160 | tf= 1 |term= last,
# index= 161 | tf= 88 |term= the
# index= 162 | tf= 2 |term= latest
# index= 163 | tf= 1 |term= data
# index= 164 | tf= 1 |term= published
# index= 165 | tf= 7 |term= by
# index= 166 | tf= 88 |term= the
# index= 167 | tf= 1 |term= federal
# index= 168 | tf= 1 |term= statistics
# index= 169 | tf= 1 |term= officeshowed
# index= 170 | tf= 21 |term= on
# index= 171 | tf= 1 |term= thursday.
# index= 172 | tf= 21 |term= on
# index= 173 | tf= 1 |term= an
# index= 174 | tf= 1 |term= annualized
# index= 175 | tf= 1 |term= basis,
# index= 176 | tf= 1 |term= germany&rsquo;s
# index= 177 | tf= 1 |term= industrial
# index= 178 | tf= 5 |term= orders
# index= 179 | tf= 2 |term= fell
# index= 180 | tf= 1 |term= 8.4%
# index= 181 | tf= 2 |term= vs.
# index= 182 | tf= 1 |term= -5.4%
# index= 183 | tf= 1 |term= expectations
# index= 184 | tf= 15 |term= and
# index= 185 | tf= 1 |term= -3.9%
# index= 186 | tf= 1 |term= last.eur/usd
# index= 187 | tf= 2 |term= upside
# index= 188 | tf= 2 |term= still
# index= 189 | tf= 1 |term= capped
# index= 190 | tf= 7 |term= by
# index= 191 | tf= 1 |term= 1.1250,
# index= 192 | tf= 9 |term= ecb
# index= 193 | tf= 1 |term= eyedthe
# index= 194 | tf= 4 |term= pair
# index= 195 | tf= 1 |term= extends
# index= 196 | tf= 88 |term= the
# index= 197 | tf= 2 |term= recovery
# index= 198 | tf= 11 |term= from
# index= 199 | tf= 4 |term= weekly
# index= 200 | tf= 3 |term= lows
# index= 201 | tf= 5 |term= near
# index= 202 | tf= 1 |term= 1.1190.
# index= 203 | tf= 88 |term= the
# index= 204 | tf= 4 |term= greenback
# index= 205 | tf= 9 |term= is
# index= 206 | tf= 1 |term= holding
# index= 207 | tf= 21 |term= on
# index= 208 | tf= 2 |term= above
# index= 209 | tf= 88 |term= the
# index= 210 | tf= 1 |term= 97.00
# index= 211 | tf= 1 |term= handle.
# index= 212 | tf= 9 |term= ecb
# index= 213 | tf= 4 |term= minutes
# index= 214 | tf= 3 |term= next
# index= 215 | tf= 20 |term= of
# index= 216 | tf= 1 |term= relevance
# index= 217 | tf= 31 |term= in
# index= 218 | tf= 88 |term= the
# index= 219 | tf= 2 |term= calendar.
# index= 220 | tf= 88 |term= the
# index= 221 | tf= 1 |term= renewed
# index= 222 | tf= 1 |term= bid
# index= 223 | tf= 1 |term= tone
# index= 224 | tf= 9 |term= around
# index= 225 | tf= 88 |term= the
# index= 226 | tf= 2 |term= european
# index= 227 | tf= 2 |term= currency
# index= 228 | tf= 4 |term= remains
# index= 229 | tf= 2 |term= unchanged
# index= 230 | tf= 31 |term= in
# index= 231 | tf= 88 |term= the
# index= 232 | tf= 4 |term= second
# index= 233 | tf= 2 |term= half
# index= 234 | tf= 20 |term= of
# index= 235 | tf= 88 |term= the
# index= 236 | tf= 2 |term= week,
# index= 237 | tf= 1 |term= motivating
# index= 238 | tf= 10 |term= eur/usd
# index= 239 | tf= 22 |term= to
# index= 240 | tf= 1 |term= extend
# index= 241 | tf= 88 |term= the
# index= 242 | tf= 1 |term= rebound
# index= 243 | tf= 11 |term= from
# index= 244 | tf= 4 |term= recent
# index= 245 | tf= 3 |term= lows
# index= 246 | tf= 31 |term= in
# index= 247 | tf= 2 |term= sub-1.1200
# index= 248 | tf= 3 |term= levels
# index= 249 | tf= 2 |term= seen
# index= 250 | tf= 2 |term= earlier
# index= 251 | tf= 31 |term= in
# index= 252 | tf= 88 |term= the
# index= 253 | tf= 1 |term= week.
# index= 254 | tf= 10 |term= eur/usd
# index= 255 | tf= 1 |term= shed
# index= 256 | tf= 3 |term= gains
# index= 257 | tf= 21 |term= on
# index= 258 | tf= 4 |term= german
# index= 259 | tf= 1 |term= data,
# index= 260 | tf= 2 |term= looks
# index= 261 | tf= 22 |term= to
# index= 262 | tf= 9 |term= ecb
# index= 263 | tf= 6 |term= spot
# index= 264 | tf= 9 |term= is
# index= 265 | tf= 1 |term= advancing
# index= 266 | tf= 12 |term= for
# index= 267 | tf= 88 |term= the
# index= 268 | tf= 4 |term= second
# index= 269 | tf= 2 |term= session
# index= 270 | tf= 31 |term= in
# index= 271 | tf= 10 |term= a
# index= 272 | tf= 2 |term= row
# index= 273 | tf= 21 |term= on
# index= 274 | tf= 1 |term= thursday
# index= 275 | tf= 4 |term= after
# index= 276 | tf= 1 |term= bottoming
# index= 277 | tf= 1 |term= out
# index= 278 | tf= 31 |term= in
# index= 279 | tf= 88 |term= the
# index= 280 | tf= 2 |term= sub-1.1200
# index= 281 | tf= 3 |term= region
# index= 282 | tf= 21 |term= on
# index= 283 | tf= 1 |term= tuesday.
# index= 284 | tf= 1 |term= better
# index= 285 | tf= 1 |term= conditions
# index= 286 | tf= 31 |term= in
# index= 287 | tf= 88 |term= the
# index= 288 | tf= 1 |term= risk-associated
# index= 289 | tf= 1 |term= universe
# index= 290 | tf= 21 |term= on
# index= 291 | tf= 88 |term= the
# index= 292 | tf= 2 |term= back
# index= 293 | tf= 20 |term= of
# index= 294 | tf= 3 |term= fresh
# index= 295 | tf= 1 |term= optimism
# index= 296 | tf= 9 |term= around
# index= 297 | tf= 88 |term= the
# index= 298 | tf= 1 |term= us-china
# index= 299 | tf= 1 |term= trade
# index= 300 | tf= 1 |term= talks
# index= 301 | tf= 15 |term= and
# index= 302 | tf= 1 |term= some
# index= 303 | tf= 1 |term= positive
# index= 304 | tf= 1 |term= headlines
# index= 305 | tf= 9 |term= around
# index= 306 | tf= 1 |term= brexit
# index= 307 | tf= 3 |term= has
# index= 308 | tf= 1 |term= been
# index= 309 | tf= 1 |term= sustaining
# index= 310 | tf= 88 |term= the
# index= 311 | tf= 1 |term= bounce
# index= 312 | tf= 31 |term= in
# index= 313 | tf= 6 |term= spot
# index= 314 | tf= 11 |term= from
# index= 315 | tf= 1 |term= lower
# index= 316 | tf= 1 |term= levels.
# index= 317 | tf= 1 |term= however,
# index= 318 | tf= 8 |term= eur
# index= 319 | tf= 1 |term= faded
# index= 320 | tf= 2 |term= earlier
# index= 321 | tf= 3 |term= gains
# index= 322 | tf= 22 |term= to
# index= 323 | tf= 88 |term= the
# index= 324 | tf= 1 |term= vicinity
# index= 325 | tf= 20 |term= of
# index= 326 | tf= 1 |term= 1.1250
# index= 327 | tf= 4 |term= after
# index= 328 | tf= 4 |term= german
# index= 329 | tf= 4 |term= factory
# index= 330 | tf= 5 |term= orders
# index= 331 | tf= 1 |term= unexpectedly
# index= 332 | tf= 2 |term= contracted
# index= 333 | tf= 13 |term= at
# index= 334 | tf= 10 |term= a
# index= 335 | tf= 3 |term= monthly
# index= 336 | tf= 2 |term= 4.6%
# index= 337 | tf= 2 |term= during
# index= 338 | tf= 2 |term= february,
# index= 339 | tf= 1 |term= missing
# index= 340 | tf= 2 |term= forecasts
# index= 341 | tf= 15 |term= and
# index= 342 | tf= 1 |term= falling
# index= 343 | tf= 1 |term= deeper
# index= 344 | tf= 1 |term= into
# index= 345 | tf= 88 |term= the
# index= 346 | tf= 2 |term= negative
# index= 347 | tf= 2 |term= ground
# index= 348 | tf= 4 |term= after
# index= 349 | tf= 1 |term= january&rsquo;s
# index= 350 | tf= 1 |term= 2.1%
# index= 351 | tf= 1 |term= contraction.
# index= 352 | tf= 1 |term= looking
# index= 353 | tf= 1 |term= ahead,
# index= 354 | tf= 88 |term= the
# index= 355 | tf= 9 |term= ecb
# index= 356 | tf= 3 |term= will
# index= 357 | tf= 1 |term= publish
# index= 358 | tf= 1 |term= its
# index= 359 | tf= 4 |term= minutes
# index= 360 | tf= 11 |term= from
# index= 361 | tf= 88 |term= the
# index= 362 | tf= 2 |term= latest
# index= 363 | tf= 1 |term= meeting,
# index= 364 | tf= 1 |term= while
# index= 365 | tf= 1 |term= initial
# index= 366 | tf= 1 |term= claims
# index= 367 | tf= 15 |term= and
# index= 368 | tf= 1 |term= challenger
# index= 369 | tf= 1 |term= job
# index= 370 | tf= 1 |term= cuts
# index= 371 | tf= 4 |term= are
# index= 372 | tf= 5 |term= expected
# index= 373 | tf= 1 |term= across
# index= 374 | tf= 88 |term= the
# index= 375 | tf= 1 |term= ocean.
# index= 376 | tf= 2 |term= what
# index= 377 | tf= 22 |term= to
# index= 378 | tf= 2 |term= look
# index= 379 | tf= 12 |term= for
# index= 380 | tf= 9 |term= around
# index= 381 | tf= 8 |term= eur
# index= 382 | tf= 31 |term= in
# index= 383 | tf= 2 |term= spite
# index= 384 | tf= 20 |term= of
# index= 385 | tf= 88 |term= the
# index= 386 | tf= 2 |term= ongoing
# index= 387 | tf= 3 |term= corrective
# index= 388 | tf= 2 |term= rebound,
# index= 389 | tf= 8 |term= eur
# index= 390 | tf= 4 |term= remains
# index= 391 | tf= 3 |term= under
# index= 392 | tf= 3 |term= pressure
# index= 393 | tf= 2 |term= following
# index= 394 | tf= 3 |term= poor
# index= 395 | tf= 3 |term= results
# index= 396 | tf= 31 |term= in
# index= 397 | tf= 2 |term= euroland.
# index= 398 | tf= 31 |term= in
# index= 399 | tf= 2 |term= fact,
# index= 400 | tf= 4 |term= recent
# index= 401 | tf= 3 |term= disappointing
# index= 402 | tf= 2 |term= readings
# index= 403 | tf= 31 |term= in
# index= 404 | tf= 88 |term= the
# index= 405 | tf= 3 |term= region
# index= 406 | tf= 2 |term= somehow
# index= 407 | tf= 2 |term= confirm
# index= 408 | tf= 4 |term= that
# index= 409 | tf= 88 |term= the
# index= 410 | tf= 2 |term= slowdown
# index= 411 | tf= 31 |term= in
# index= 412 | tf= 88 |term= the
# index= 413 | tf= 2 |term= bloc
# index= 414 | tf= 15 |term= and
# index= 415 | tf= 88 |term= the
# index= 416 | tf= 2 |term= &lsquo;patient-for-longer&rsquo;
# index= 417 | tf= 2 |term= stance
# index= 418 | tf= 11 |term= from
# index= 419 | tf= 88 |term= the
# index= 420 | tf= 9 |term= ecb
# index= 421 | tf= 4 |term= could
# index= 422 | tf= 4 |term= be
# index= 423 | tf= 3 |term= among
# index= 424 | tf= 2 |term= us
# index= 425 | tf= 12 |term= for
# index= 426 | tf= 2 |term= longer
# index= 427 | tf= 3 |term= than
# index= 428 | tf= 2 |term= expected.
# index= 429 | tf= 2 |term= against
# index= 430 | tf= 88 |term= the
# index= 431 | tf= 2 |term= backdrop
# index= 432 | tf= 20 |term= of
# index= 433 | tf= 2 |term= souring
# index= 434 | tf= 2 |term= risk-appetite
# index= 435 | tf= 2 |term= trend,
# index= 436 | tf= 88 |term= the
# index= 437 | tf= 4 |term= greenback
# index= 438 | tf= 2 |term= should
# index= 439 | tf= 4 |term= emerge
# index= 440 | tf= 2 |term= stronger
# index= 441 | tf= 15 |term= and
# index= 442 | tf= 9 |term= is
# index= 443 | tf= 5 |term= expected
# index= 444 | tf= 22 |term= to
# index= 445 | tf= 2 |term= keep
# index= 446 | tf= 2 |term= weighing
# index= 447 | tf= 21 |term= on
# index= 448 | tf= 6 |term= spot
# index= 449 | tf= 12 |term= for
# index= 450 | tf= 88 |term= the
# index= 451 | tf= 5 |term= time
# index= 452 | tf= 2 |term= being.
# index= 453 | tf= 21 |term= on
# index= 454 | tf= 88 |term= the
# index= 455 | tf= 2 |term= political
# index= 456 | tf= 2 |term= front,
# index= 457 | tf= 2 |term= headwinds
# index= 458 | tf= 4 |term= are
# index= 459 | tf= 5 |term= expected
# index= 460 | tf= 22 |term= to
# index= 461 | tf= 4 |term= emerge
# index= 462 | tf= 31 |term= in
# index= 463 | tf= 3 |term= light
# index= 464 | tf= 20 |term= of
# index= 465 | tf= 88 |term= the
# index= 466 | tf= 2 |term= upcoming
# index= 467 | tf= 1 |term= eu
# index= 468 | tf= 1 |term= parliamentary
# index= 469 | tf= 1 |term= elections,
# index= 470 | tf= 3 |term= where
# index= 471 | tf= 88 |term= the
# index= 472 | tf= 1 |term= focus
# index= 473 | tf= 20 |term= of
# index= 474 | tf= 2 |term= attention
# index= 475 | tf= 3 |term= will
# index= 476 | tf= 4 |term= be
# index= 477 | tf= 21 |term= on
# index= 478 | tf= 88 |term= the
# index= 479 | tf= 1 |term= potential
# index= 480 | tf= 1 |term= increase
# index= 481 | tf= 20 |term= of
# index= 482 | tf= 88 |term= the
# index= 483 | tf= 1 |term= populist
# index= 484 | tf= 1 |term= option
# index= 485 | tf= 3 |term= among
# index= 486 | tf= 1 |term= voters.
# index= 487 | tf= 10 |term= eur/usd
# index= 488 | tf= 3 |term= levels
# index= 489 | tf= 22 |term= to
# index= 490 | tf= 1 |term= watch
# index= 491 | tf= 13 |term= at
# index= 492 | tf= 88 |term= the
# index= 493 | tf= 1 |term= moment,
# index= 494 | tf= 88 |term= the
# index= 495 | tf= 4 |term= pair
# index= 496 | tf= 9 |term= is
# index= 497 | tf= 1 |term= gaining
# index= 498 | tf= 1 |term= 0.08%
# index= 499 | tf= 13 |term= at
# index= 500 | tf= 1 |term= 1.1240
# index= 501 | tf= 15 |term= and
# index= 502 | tf= 10 |term= a
# index= 503 | tf= 1 |term= break
# index= 504 | tf= 2 |term= above
# index= 505 | tf= 1 |term= 1.1254
# index= 506 | tf= 1 |term= (high
# index= 507 | tf= 1 |term= apr.1)
# index= 508 | tf= 1 |term= would
# index= 509 | tf= 1 |term= target
# index= 510 | tf= 1 |term= 1.1277
# index= 511 | tf= 1 |term= (21-day
# index= 512 | tf= 1 |term= sma)
# index= 513 | tf= 1 |term= en
# index= 514 | tf= 1 |term= route
# index= 515 | tf= 22 |term= to
# index= 516 | tf= 3 |term= 1.1338
# index= 517 | tf= 1 |term= (200-week
# index= 518 | tf= 1 |term= sma).
# index= 519 | tf= 21 |term= on
# index= 520 | tf= 88 |term= the
# index= 521 | tf= 1 |term= other
# index= 522 | tf= 1 |term= hand,
# index= 523 | tf= 1 |term= immediate
# index= 524 | tf= 1 |term= contention
# index= 525 | tf= 2 |term= emerges
# index= 526 | tf= 13 |term= at
# index= 527 | tf= 1 |term= 1.1183
# index= 528 | tf= 2 |term= (low
# index= 529 | tf= 1 |term= apr.2)
# index= 530 | tf= 1 |term= followed
# index= 531 | tf= 7 |term= by
# index= 532 | tf= 2 |term= 1.1176
# index= 533 | tf= 2 |term= (low
# index= 534 | tf= 1 |term= mar.7)
# index= 535 | tf= 15 |term= and
# index= 536 | tf= 1 |term= finally
# index= 537 | tf= 1 |term= 1.1118
# index= 538 | tf= 1 |term= (monthly
# index= 539 | tf= 4 |term= low
# index= 540 | tf= 1 |term= jun.20
# index= 541 | tf= 1 |term= 2017).eur/usd
# index= 542 | tf= 1 |term= technical
# index= 543 | tf= 1 |term= analysis:
# index= 544 | tf= 3 |term= corrective
# index= 545 | tf= 2 |term= upside
# index= 546 | tf= 4 |term= could
# index= 547 | tf= 1 |term= test
# index= 548 | tf= 88 |term= the
# index= 549 | tf= 3 |term= 200-week
# index= 550 | tf= 4 |term= sma
# index= 551 | tf= 13 |term= at
# index= 552 | tf= 1 |term= 1.1338the
# index= 553 | tf= 1 |term= squeeze
# index= 554 | tf= 2 |term= higher
# index= 555 | tf= 31 |term= in
# index= 556 | tf= 88 |term= the
# index= 557 | tf= 4 |term= pair
# index= 558 | tf= 2 |term= still
# index= 559 | tf= 3 |term= has
# index= 560 | tf= 1 |term= legs,
# index= 561 | tf= 2 |term= although
# index= 562 | tf= 6 |term= spot
# index= 563 | tf= 9 |term= is
# index= 564 | tf= 1 |term= struggling
# index= 565 | tf= 22 |term= to
# index= 566 | tf= 1 |term= leave
# index= 567 | tf= 1 |term= behind
# index= 568 | tf= 88 |term= the
# index= 569 | tf= 4 |term= area
# index= 570 | tf= 20 |term= of
# index= 571 | tf= 4 |term= weekly
# index= 572 | tf= 1 |term= tops
# index= 573 | tf= 9 |term= around
# index= 574 | tf= 1 |term= 1.1250.
# index= 575 | tf= 88 |term= the
# index= 576 | tf= 1 |term= 10-day
# index= 577 | tf= 4 |term= sma
# index= 578 | tf= 13 |term= at
# index= 579 | tf= 1 |term= 1.1241
# index= 580 | tf= 1 |term= also
# index= 581 | tf= 1 |term= reinforces
# index= 582 | tf= 3 |term= this
# index= 583 | tf= 4 |term= area
# index= 584 | tf= 20 |term= of
# index= 585 | tf= 1 |term= resistance.
# index= 586 | tf= 1 |term= if
# index= 587 | tf= 3 |term= this
# index= 588 | tf= 4 |term= area
# index= 589 | tf= 9 |term= is
# index= 590 | tf= 1 |term= cleared
# index= 591 | tf= 21 |term= on
# index= 592 | tf= 10 |term= a
# index= 593 | tf= 1 |term= convincing
# index= 594 | tf= 1 |term= fashion,
# index= 595 | tf= 3 |term= further
# index= 596 | tf= 3 |term= gains
# index= 597 | tf= 4 |term= could
# index= 598 | tf= 1 |term= see
# index= 599 | tf= 88 |term= the
# index= 600 | tf= 1 |term= critical
# index= 601 | tf= 3 |term= 200-week
# index= 602 | tf= 4 |term= sma
# index= 603 | tf= 13 |term= at
# index= 604 | tf= 3 |term= 1.1338
# index= 605 | tf= 1 |term= re-visited
# index= 606 | tf= 31 |term= in
# index= 607 | tf= 88 |term= the
# index= 608 | tf= 5 |term= near
# index= 609 | tf= 1 |term= term.
# index= 610 | tf= 3 |term= further
# index= 611 | tf= 1 |term= out,
# index= 612 | tf= 88 |term= the
# index= 613 | tf= 1 |term= bearish
# index= 614 | tf= 1 |term= view
# index= 615 | tf= 21 |term= on
# index= 616 | tf= 10 |term= eur/usd
# index= 617 | tf= 1 |term= stays
# index= 618 | tf= 2 |term= unchanged
# index= 619 | tf= 2 |term= as
# index= 620 | tf= 1 |term= long
# index= 621 | tf= 2 |term= as
# index= 622 | tf= 88 |term= the
# index= 623 | tf= 1 |term= 6-month
# index= 624 | tf= 2 |term= resistance
# index= 625 | tf= 1 |term= line,
# index= 626 | tf= 5 |term= today
# index= 627 | tf= 13 |term= at
# index= 628 | tf= 1 |term= 1.1380,
# index= 629 | tf= 1 |term= caps
# index= 630 | tf= 88 |term= the
# index= 631 | tf= 1 |term= upside.
# index= 632 | tf= 10 |term= eur/usd
# index= 633 | tf= 21 |term= daily
# index= 634 | tf= 1 |term= chart
# index= 635 | tf= 10 |term= eur/usd
# index= 636 | tf= 1 |term= overview
# index= 637 | tf= 5 |term= today
# index= 638 | tf= 2 |term= last
# index= 639 | tf= 1 |term= price
# index= 640 | tf= 1 |term= 1.1235
# index= 641 | tf= 5 |term= today
# index= 642 | tf= 21 |term= daily
# index= 643 | tf= 2 |term= change
# index= 644 | tf= 1 |term= 17
# index= 645 | tf= 5 |term= today
# index= 646 | tf= 21 |term= daily
# index= 647 | tf= 2 |term= change
# index= 648 | tf= 1 |term= %
# index= 649 | tf= 1 |term= 0.03
# index= 650 | tf= 5 |term= today
# index= 651 | tf= 21 |term= daily
# index= 652 | tf= 3 |term= open
# index= 653 | tf= 1 |term= 1.1232
# index= 654 | tf= 1 |term= trends
# index= 655 | tf= 21 |term= daily
# index= 656 | tf= 1 |term= sma20
# index= 657 | tf= 1 |term= 1.128
# index= 658 | tf= 21 |term= daily
# index= 659 | tf= 1 |term= sma50
# index= 660 | tf= 1 |term= 1.1328
# index= 661 | tf= 21 |term= daily
# index= 662 | tf= 1 |term= sma100
# index= 663 | tf= 1 |term= 1.136
# index= 664 | tf= 21 |term= daily
# index= 665 | tf= 1 |term= sma200
# index= 666 | tf= 1 |term= 1.1464
# index= 667 | tf= 3 |term= levels
# index= 668 | tf= 6 |term= previous
# index= 669 | tf= 21 |term= daily
# index= 670 | tf= 3 |term= high
# index= 671 | tf= 1 |term= 1.1256
# index= 672 | tf= 6 |term= previous
# index= 673 | tf= 21 |term= daily
# index= 674 | tf= 4 |term= low
# index= 675 | tf= 1 |term= 1.12
# index= 676 | tf= 6 |term= previous
# index= 677 | tf= 4 |term= weekly
# index= 678 | tf= 3 |term= high
# index= 679 | tf= 1 |term= 1.1332
# index= 680 | tf= 6 |term= previous
# index= 681 | tf= 4 |term= weekly
# index= 682 | tf= 4 |term= low
# index= 683 | tf= 1 |term= 1.1209
# index= 684 | tf= 6 |term= previous
# index= 685 | tf= 3 |term= monthly
# index= 686 | tf= 3 |term= high
# index= 687 | tf= 1 |term= 1.1448
# index= 688 | tf= 6 |term= previous
# index= 689 | tf= 3 |term= monthly
# index= 690 | tf= 4 |term= low
# index= 691 | tf= 2 |term= 1.1176
# index= 692 | tf= 21 |term= daily
# index= 693 | tf= 2 |term= fibonacci
# index= 694 | tf= 1 |term= 38.2%
# index= 695 | tf= 1 |term= 1.1234
# index= 696 | tf= 21 |term= daily
# index= 697 | tf= 2 |term= fibonacci
# index= 698 | tf= 1 |term= 61.8%
# index= 699 | tf= 1 |term= 1.1221
# index= 700 | tf= 21 |term= daily
# index= 701 | tf= 6 |term= pivot
# index= 702 | tf= 6 |term= point
# index= 703 | tf= 1 |term= s1
# index= 704 | tf= 1 |term= 1.1203
# index= 705 | tf= 21 |term= daily
# index= 706 | tf= 6 |term= pivot
# index= 707 | tf= 6 |term= point
# index= 708 | tf= 1 |term= s2
# index= 709 | tf= 1 |term= 1.1174
# index= 710 | tf= 21 |term= daily
# index= 711 | tf= 6 |term= pivot
# index= 712 | tf= 6 |term= point
# index= 713 | tf= 1 |term= s3
# index= 714 | tf= 1 |term= 1.1147
# index= 715 | tf= 21 |term= daily
# index= 716 | tf= 6 |term= pivot
# index= 717 | tf= 6 |term= point
# index= 718 | tf= 1 |term= r1
# index= 719 | tf= 1 |term= 1.1259
# index= 720 | tf= 21 |term= daily
# index= 721 | tf= 6 |term= pivot
# index= 722 | tf= 6 |term= point
# index= 723 | tf= 1 |term= r2
# index= 724 | tf= 1 |term= 1.1285
# index= 725 | tf= 21 |term= daily
# index= 726 | tf= 6 |term= pivot
# index= 727 | tf= 6 |term= point
# index= 728 | tf= 1 |term= r3
# index= 729 | tf= 1 |term= 1.1314eur/usd
# index= 730 | tf= 1 |term= drops
# index= 731 | tf= 22 |term= to
# index= 732 | tf= 21 |term= daily
# index= 733 | tf= 3 |term= lows
# index= 734 | tf= 5 |term= near
# index= 735 | tf= 2 |term= 1.1220
# index= 736 | tf= 1 |term= ahead
# index= 737 | tf= 20 |term= of
# index= 738 | tf= 1 |term= ecbthe
# index= 739 | tf= 4 |term= pair
# index= 740 | tf= 1 |term= comes
# index= 741 | tf= 3 |term= under
# index= 742 | tf= 3 |term= pressure
# index= 743 | tf= 21 |term= on
# index= 744 | tf= 1 |term= usd-buying.
# index= 745 | tf= 1 |term= dxy
# index= 746 | tf= 1 |term= moves
# index= 747 | tf= 2 |term= higher
# index= 748 | tf= 15 |term= and
# index= 749 | tf= 1 |term= clinched
# index= 750 | tf= 1 |term= highs
# index= 751 | tf= 5 |term= near
# index= 752 | tf= 1 |term= 97.20.
# index= 753 | tf= 9 |term= ecb
# index= 754 | tf= 4 |term= minutes
# index= 755 | tf= 1 |term= coming
# index= 756 | tf= 2 |term= up
# index= 757 | tf= 3 |term= next
# index= 758 | tf= 31 |term= in
# index= 759 | tf= 88 |term= the
# index= 760 | tf= 2 |term= calendar.
# index= 761 | tf= 10 |term= a
# index= 762 | tf= 1 |term= bout
# index= 763 | tf= 20 |term= of
# index= 764 | tf= 3 |term= fresh
# index= 765 | tf= 1 |term= buying
# index= 766 | tf= 2 |term= interest
# index= 767 | tf= 9 |term= around
# index= 768 | tf= 88 |term= the
# index= 769 | tf= 4 |term= greenback
# index= 770 | tf= 9 |term= is
# index= 771 | tf= 1 |term= forcing
# index= 772 | tf= 10 |term= eur/usd
# index= 773 | tf= 22 |term= to
# index= 774 | tf= 1 |term= recede
# index= 775 | tf= 22 |term= to
# index= 776 | tf= 88 |term= the
# index= 777 | tf= 2 |term= 1.1220
# index= 778 | tf= 1 |term= region,
# index= 779 | tf= 1 |term= recording
# index= 780 | tf= 13 |term= at
# index= 781 | tf= 88 |term= the
# index= 782 | tf= 1 |term= same
# index= 783 | tf= 5 |term= time
# index= 784 | tf= 3 |term= fresh
# index= 785 | tf= 21 |term= daily
# index= 786 | tf= 1 |term= lows.
# index= 787 | tf= 10 |term= eur/usd
# index= 788 | tf= 2 |term= looks
# index= 789 | tf= 22 |term= to
# index= 790 | tf= 9 |term= ecb
# index= 791 | tf= 1 |term= sellers
# index= 792 | tf= 9 |term= around
# index= 793 | tf= 88 |term= the
# index= 794 | tf= 1 |term= shared
# index= 795 | tf= 2 |term= currency
# index= 796 | tf= 1 |term= appear
# index= 797 | tf= 22 |term= to
# index= 798 | tf= 1 |term= have
# index= 799 | tf= 1 |term= regained
# index= 800 | tf= 88 |term= the
# index= 801 | tf= 1 |term= upper
# index= 802 | tf= 1 |term= hand
# index= 803 | tf= 31 |term= in
# index= 804 | tf= 88 |term= the
# index= 805 | tf= 4 |term= second
# index= 806 | tf= 2 |term= half
# index= 807 | tf= 20 |term= of
# index= 808 | tf= 88 |term= the
# index= 809 | tf= 2 |term= week,
# index= 810 | tf= 1 |term= pushing
# index= 811 | tf= 6 |term= spot
# index= 812 | tf= 22 |term= to
# index= 813 | tf= 88 |term= the
# index= 814 | tf= 4 |term= area
# index= 815 | tf= 1 |term= closer
# index= 816 | tf= 22 |term= to
# index= 817 | tf= 88 |term= the
# index= 818 | tf= 1 |term= key
# index= 819 | tf= 1 |term= support
# index= 820 | tf= 13 |term= at
# index= 821 | tf= 1 |term= 1.1200
# index= 822 | tf= 88 |term= the
# index= 823 | tf= 1 |term= figure
# index= 824 | tf= 2 |term= during
# index= 825 | tf= 88 |term= the
# index= 826 | tf= 2 |term= european
# index= 827 | tf= 1 |term= morning.
# index= 828 | tf= 8 |term= eur
# index= 829 | tf= 3 |term= has
# index= 830 | tf= 1 |term= initially
# index= 831 | tf= 1 |term= suffered
# index= 832 | tf= 1 |term= another
# index= 833 | tf= 3 |term= disappointing
# index= 834 | tf= 3 |term= results
# index= 835 | tf= 11 |term= from
# index= 836 | tf= 88 |term= the
# index= 837 | tf= 4 |term= german
# index= 838 | tf= 1 |term= docket,
# index= 839 | tf= 3 |term= where
# index= 840 | tf= 4 |term= factory
# index= 841 | tf= 5 |term= orders
# index= 842 | tf= 2 |term= contracted
# index= 843 | tf= 1 |term= sharply
# index= 844 | tf= 7 |term= by
# index= 845 | tf= 2 |term= 4.6%
# index= 846 | tf= 31 |term= in
# index= 847 | tf= 1 |term= february
# index= 848 | tf= 11 |term= from
# index= 849 | tf= 10 |term= a
# index= 850 | tf= 3 |term= month
# index= 851 | tf= 1 |term= earlier,
# index= 852 | tf= 2 |term= all
# index= 853 | tf= 2 |term= adding
# index= 854 | tf= 22 |term= to
# index= 855 | tf= 2 |term= last
# index= 856 | tf= 1 |term= week&rsquo;s
# index= 857 | tf= 3 |term= poor
# index= 858 | tf= 1 |term= prints
# index= 859 | tf= 11 |term= from
# index= 860 | tf= 1 |term= advanced
# index= 861 | tf= 2 |term= inflation
# index= 862 | tf= 1 |term= figures.
# index= 863 | tf= 1 |term= moving
# index= 864 | tf= 1 |term= forward,
# index= 865 | tf= 88 |term= the
# index= 866 | tf= 9 |term= ecb
# index= 867 | tf= 4 |term= minutes
# index= 868 | tf= 4 |term= are
# index= 869 | tf= 3 |term= next
# index= 870 | tf= 21 |term= on
# index= 871 | tf= 1 |term= tap,
# index= 872 | tf= 3 |term= where
# index= 873 | tf= 2 |term= all
# index= 874 | tf= 88 |term= the
# index= 875 | tf= 2 |term= attention
# index= 876 | tf= 3 |term= will
# index= 877 | tf= 4 |term= be
# index= 878 | tf= 21 |term= on
# index= 879 | tf= 1 |term= discussions
# index= 880 | tf= 1 |term= over
# index= 881 | tf= 88 |term= the
# index= 882 | tf= 1 |term= announced
# index= 883 | tf= 1 |term= tltro-iii
# index= 884 | tf= 15 |term= and
# index= 885 | tf= 1 |term= members&rsquo;
# index= 886 | tf= 1 |term= views
# index= 887 | tf= 1 |term= regarding
# index= 888 | tf= 88 |term= the
# index= 889 | tf= 1 |term= new
# index= 890 | tf= 1 |term= (and
# index= 891 | tf= 1 |term= lower)
# index= 892 | tf= 2 |term= forecasts
# index= 893 | tf= 12 |term= for
# index= 894 | tf= 2 |term= inflation
# index= 895 | tf= 15 |term= and
# index= 896 | tf= 1 |term= growth
# index= 897 | tf= 31 |term= in
# index= 898 | tf= 88 |term= the
# index= 899 | tf= 1 |term= region.
# index= 900 | tf= 2 |term= what
# index= 901 | tf= 22 |term= to
# index= 902 | tf= 2 |term= look
# index= 903 | tf= 12 |term= for
# index= 904 | tf= 9 |term= around
# index= 905 | tf= 8 |term= eur
# index= 906 | tf= 31 |term= in
# index= 907 | tf= 2 |term= spite
# index= 908 | tf= 20 |term= of
# index= 909 | tf= 88 |term= the
# index= 910 | tf= 2 |term= ongoing
# index= 911 | tf= 3 |term= corrective
# index= 912 | tf= 2 |term= rebound,
# index= 913 | tf= 8 |term= eur
# index= 914 | tf= 4 |term= remains
# index= 915 | tf= 3 |term= under
# index= 916 | tf= 3 |term= pressure
# index= 917 | tf= 2 |term= following
# index= 918 | tf= 3 |term= poor
# index= 919 | tf= 3 |term= results
# index= 920 | tf= 31 |term= in
# index= 921 | tf= 2 |term= euroland.
# index= 922 | tf= 31 |term= in
# index= 923 | tf= 2 |term= fact,
# index= 924 | tf= 4 |term= recent
# index= 925 | tf= 3 |term= disappointing
# index= 926 | tf= 2 |term= readings
# index= 927 | tf= 31 |term= in
# index= 928 | tf= 88 |term= the
# index= 929 | tf= 3 |term= region
# index= 930 | tf= 2 |term= somehow
# index= 931 | tf= 2 |term= confirm
# index= 932 | tf= 4 |term= that
# index= 933 | tf= 88 |term= the
# index= 934 | tf= 2 |term= slowdown
# index= 935 | tf= 31 |term= in
# index= 936 | tf= 88 |term= the
# index= 937 | tf= 2 |term= bloc
# index= 938 | tf= 15 |term= and
# index= 939 | tf= 88 |term= the
# index= 940 | tf= 2 |term= &lsquo;patient-for-longer&rsquo;
# index= 941 | tf= 2 |term= stance
# index= 942 | tf= 11 |term= from
# index= 943 | tf= 88 |term= the
# index= 944 | tf= 9 |term= ecb
# index= 945 | tf= 4 |term= could
# index= 946 | tf= 4 |term= be
# index= 947 | tf= 3 |term= among
# index= 948 | tf= 2 |term= us
# index= 949 | tf= 12 |term= for
# index= 950 | tf= 2 |term= longer
# index= 951 | tf= 3 |term= than
# index= 952 | tf= 2 |term= expected.
# index= 953 | tf= 2 |term= against
# index= 954 | tf= 88 |term= the
# index= 955 | tf= 2 |term= backdrop
# index= 956 | tf= 20 |term= of
# index= 957 | tf= 2 |term= souring
# index= 958 | tf= 2 |term= risk-appetite
# index= 959 | tf= 2 |term= trend,
# index= 960 | tf= 88 |term= the
# index= 961 | tf= 4 |term= greenback
# index= 962 | tf= 2 |term= should
# index= 963 | tf= 4 |term= emerge
# index= 964 | tf= 2 |term= stronger
# index= 965 | tf= 15 |term= and
# index= 966 | tf= 9 |term= is
# index= 967 | tf= 5 |term= expected
# index= 968 | tf= 22 |term= to
# index= 969 | tf= 2 |term= keep
# index= 970 | tf= 2 |term= weighing
# index= 971 | tf= 21 |term= on
# index= 972 | tf= 6 |term= spot
# index= 973 | tf= 12 |term= for
# index= 974 | tf= 88 |term= the
# index= 975 | tf= 5 |term= time
# index= 976 | tf= 2 |term= being.
# index= 977 | tf= 21 |term= on
# index= 978 | tf= 88 |term= the
# index= 979 | tf= 2 |term= political
# index= 980 | tf= 2 |term= front,
# index= 981 | tf= 2 |term= headwinds
# index= 982 | tf= 4 |term= are
# index= 983 | tf= 5 |term= expected
# index= 984 | tf= 22 |term= to
# index= 985 | tf= 4 |term= emerge
# index= 986 | tf= 31 |term= in
# index= 987 | tf= 3 |term= light
# index= 988 | tf= 20 |term= of
# index= 989 | tf= 88 |term= the
# index= 990 | tf= 2 |term= upcoming

# %% [markdown]
# ## 2- Remove Numbers & Tags
# __________________________________________

# %%
def All_Document_To_Once(*args):
    corpus_args=[]
    for item in args:
        corpus_args.append(item+item)
    return corpus_args

# %%
All_Document_To_Once(book1,book2,book3,book4,book5,book6,book7,book8,book9,book10)
type(All_Document_To_Once)
# Out:
# function

# %% [markdown]
# ## 3- Word Tokenization
# __________________________________________

# %% [markdown]
# ## 4- Remove Stop Words
# __________________________________________

# %% [markdown]
# #### Define Typical Stop Words manualy :
# ###### from this Website: https://www.ranks.nl/stopwords

# %%
MyStopWords= ["a","about","above","after","again","against","all","am","an","and","any","are",
"aren't","as","at","be","because","been","before","being","below","between","both","but","by",
"can't","cannot","could","couldn't","did","didn't","do","does","doesn't","doing","don't",
"down","during","each","few","for","from","further","had","hadn't","has","hasn't","have",
"haven't","having","he","he'd","he'll","he's","her","here","here's","hers","herself","him",
"himself","his","how","how's","i","i'd","i'll","i'm" ,"i've","if","in","into","is","isn't",
"it","it's","its","itself","let's","me","more","most","mustn't","my","myself","no","nor","not",
"of","off","on","once","only","or","other","ought","our","ours","ourselves","out","over","own",
"same","shan't","she","she'd","she'll","she's","should","shouldn't","so","some","such","than",
"that","that's","the","their","theirs","them","themselves","then","there","there's","these",
"they","they'd","they'll","they're","they've","this","those","through","to","too","under",
"until","up","very","was","wasn't","we","we'd","we'll","we're","we've","were","weren't","what",
"what's","when","when's","where","where's","which","while","who","who's","whom","why","why's",
"with","won't","would","wouldn't","you","you'd","you'll","you're","you've","your","yours",
"yourself","yourselves"
]

# %%
# removing STOP-WORDS  with upper wordlist

result = [i for i in book1_S if not i in MyStopWords]

print("before remove stop-words : ", len(book1_S),"words.",
      "\nafter count new words    : ", len(result),"words.","\n ________________________________________\n")

print (result)
# Out:
# before remove stop-words :  991 words.
# after count new words    :  659 words.
#  ________________________________________
#
# ['eur', 'futures:', 'recovery', 'seen', 'limitedin', 'light', 'preliminary', 'figures', 'eur', 'futures', 'markets', 'cme', 'group,', 'investors', 'scaled', 'back', 'open', 'interest', 'positions', '2k', 'contracts', 'wednesday', 'thursday&rsquo;s', 'final', '497,717', 'contracts.', 'volume,', 'instead', 'rose', 'first', 'time', 'four', 'consecutive', 'daily', 'drops,', 'time', 'around', '14.4k', 'contracts.', 'eur/usd', 'faces', 'strong', 'resistance', '1.1338', 'eur/usd', 'recovering', 'ground', 'second', 'session', 'row', 'amidst', 'rising', 'volume', 'shrinking', 'open', 'interest.', 'said,', 'continuation', 'move', 'remains', 'cards', 'near', 'term,', 'although', 'tough', 'barrier', 'emerges', '200-week', 'sma', '1.1338.german', 'factory', 'orders', 'slump', '4.2%', 'feb,', 'negative', 'surprise', '(eur', 'turns', 'lower)the', 'german', 'factory', 'orders', 'fell', 'month', 'february,', 'adding', 'recent', 'signs', 'europe&rsquo;s', 'largest', 'economy', 'subdued', 'start', '2019', 'contracts', 'goods', '&lsquo;made', 'germany&rsquo;', '4.2%', 'month', 'vs.', '0.3%', 'forecast', '-2.6%', 'last,', 'latest', 'data', 'published', 'federal', 'statistics', 'officeshowed', 'thursday.', 'annualized', 'basis,', 'germany&rsquo;s', 'industrial', 'orders', 'fell', '8.4%', 'vs.', '-5.4%', 'expectations', '-3.9%', 'last.eur/usd', 'upside', 'still', 'capped', '1.1250,', 'ecb', 'eyedthe', 'pair', 'extends', 'recovery', 'weekly', 'lows', 'near', '1.1190.', 'greenback', 'holding', '97.00', 'handle.', 'ecb', 'minutes', 'next', 'relevance', 'calendar.', 'renewed', 'bid', 'tone', 'around', 'european', 'currency', 'remains', 'unchanged', 'second', 'half', 'week,', 'motivating', 'eur/usd', 'extend', 'rebound', 'recent', 'lows', 'sub-1.1200', 'levels', 'seen', 'earlier', 'week.', 'eur/usd', 'shed', 'gains', 'german', 'data,', 'looks', 'ecb', 'spot', 'advancing', 'second', 'session', 'row', 'thursday', 'bottoming', 'sub-1.1200', 'region', 'tuesday.', 'better', 'conditions', 'risk-associated', 'universe', 'back', 'fresh', 'optimism', 'around', 'us-china', 'trade', 'talks', 'positive', 'headlines', 'around', 'brexit', 'sustaining', 'bounce', 'spot', 'lower', 'levels.', 'however,', 'eur', 'faded', 'earlier', 'gains', 'vicinity', '1.1250', 'german', 'factory', 'orders', 'unexpectedly', 'contracted', 'monthly', '4.6%', 'february,', 'missing', 'forecasts', 'falling', 'deeper', 'negative', 'ground', 'january&rsquo;s', '2.1%', 'contraction.', 'looking', 'ahead,', 'ecb', 'will', 'publish', 'minutes', 'latest', 'meeting,', 'initial', 'claims', 'challenger', 'job', 'cuts', 'expected', 'across', 'ocean.', 'look', 'around', 'eur', 'spite', 'ongoing', 'corrective', 'rebound,', 'eur', 'remains', 'pressure', 'following', 'poor', 'results', 'euroland.', 'fact,', 'recent', 'disappointing', 'readings', 'region', 'somehow', 'confirm', 'slowdown', 'bloc', '&lsquo;patient-for-longer&rsquo;', 'stance', 'ecb', 'among', 'us', 'longer', 'expected.', 'backdrop', 'souring', 'risk-appetite', 'trend,', 'greenback', 'emerge', 'stronger', 'expected', 'keep', 'weighing', 'spot', 'time', 'being.', 'political', 'front,', 'headwinds', 'expected', 'emerge', 'light', 'upcoming', 'eu', 'parliamentary', 'elections,', 'focus', 'attention', 'will', 'potential', 'increase', 'populist', 'option', 'among', 'voters.', 'eur/usd', 'levels', 'watch', 'moment,', 'pair', 'gaining', '0.08%', '1.1240', 'break', '1.1254', '(high', 'apr.1)', 'target', '1.1277', '(21-day', 'sma)', 'en', 'route', '1.1338', '(200-week', 'sma).', 'hand,', 'immediate', 'contention', 'emerges', '1.1183', '(low', 'apr.2)', 'followed', '1.1176', '(low', 'mar.7)', 'finally', '1.1118', '(monthly', 'low', 'jun.20', '2017).eur/usd', 'technical', 'analysis:', 'corrective', 'upside', 'test', '200-week', 'sma', '1.1338the', 'squeeze', 'higher', 'pair', 'still', 'legs,', 'although', 'spot', 'struggling', 'leave', 'behind', 'area', 'weekly', 'tops', 'around', '1.1250.', '10-day', 'sma', '1.1241', 'also', 'reinforces', 'area', 'resis ...

# %% [markdown]
# ## 5- Display using Graphs
#
# #### WordCloud, Liniear Graph, Bar Graph
# __________________________________________

# %%
# importing all necessery modules 
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import matplotlib.pyplot as plt 
import pandas as pd

# %%
word = ','.join(result)

wordcloud = WordCloud(max_font_size=35, max_words=len(word), background_color='white').generate(word)

plt.figure(figsize=(14,10))
plt.axis('off')
plt.imshow(wordcloud, interpolation='bilinear')
plt.show()

# %%
def DisplayAsWordCloudGraph(document):
    word = ','.join(result)
    wordcloud = WordCloud(max_font_size=35, max_words=len(word), background_color='white').generate(word)
    
    plt.figure(figsize=(14,10))
    plt.axis('off')
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.show()

# %%
DisplayAsWordCloudGraph(doc_5)
